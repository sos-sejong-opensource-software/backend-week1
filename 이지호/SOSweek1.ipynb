# %% [markdown]
# # 영화 정보를 바탕으로 다양한 그래프를 그려보기
#
# ###### 아래는 영화 정보

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

data = {
    '영화' : ['명량', '극한직업', '신과함께-죄와 벌', '국제시장', '괴물', '도둑들', '7번방의 선물', '암살'],
    '개봉 연도' : [2014, 2019, 2017, 2014, 2006, 2012, 2013, 2015],
    '관객 수' : [1761, 1626, 1441, 1426, 1301, 1298, 1281, 1270], # (단위 : 만 명)
    '평점' : [8.88, 9.20, 8.73, 9.16, 8.62, 7.64, 8.83, 9.10]
}
df= pd.DataFrame(data)
print(df)
# Out:
#           영화  개봉 연도  관객 수    평점
# 0         명량   2014  1761  8.88
# 1       극한직업   2019  1626  9.20
# 2  신과함께-죄와 벌   2017  1441  8.73
# 3       국제시장   2014  1426  9.16
# 4         괴물   2006  1301  8.62
# 5        도둑들   2012  1298  7.64
# 6    7번방의 선물   2013  1281  8.83
# 7         암살   2015  1270  9.10

# %% [markdown]
# ### 1. x축은 영화, y축은 평점인 막대 그래프를 통해 나타내기

# %%
plt.bar(df['영화'], df['평점'])
plt.title('귝내 Top 8 영화 평점 정보')
plt.xlabel('영화')
plt.xticks(rotation=90)
plt.ylabel('평점')
plt.show()

# %% [markdown]
# ### 2. 개봉 연도별 평점 변화 추이를 꺾은선 그래프를 통해 나타내기

# %%
df_group = df.groupby('개봉 연도').mean()
df_group
plt.plot(df_group.index, df_group['평점'])
plt.show()
# Out:
# C:\Users\이지호\AppData\Local\Temp\ipykernel_46476\959157742.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_group = df.groupby('개봉 연도').mean()

# %% [markdown]
# ### 3. 평점이 9점 이상인 영화의 비율을 확인할 수 있는 원 그래프 그리기

# %%
#3. 
filt = df['평점'] >= 9.0
values = [len(df[filt]), len(df[~filt])]
labels = ['9점 이상', '9점 미만']

plt.pie(values, labels=labels, autopct='%.1f%%')
plt.legend(loc=(1, 0.3))
plt.show()
